# %%
import pandas as pd
import numpy as np
import seaborn as sns
import networkx as nx
from pyvis.network import Network
import matplotlib.pyplot as plt

# %%
from pyvis.network import Network
import pandas as pd

vienna_net = Network(height='750px', 
                  width='100%', 
                  bgcolor='#222222', 
                  font_color='white', 
                  notebook = True)

# set the physics layout of the network
vienna_net.barnes_hut()
vienna_data = pd.read_csv('Vienna subway.csv',
                      delimiter= ';')
vienna_data.tail()
# Out:
#                 Start              Stop  Line  Color
# 99          Spittelau     Jaegerstrasse     6  brown
# 100     Jaegerstrasse  Dresdner strasse     6  brown
# 101  Dresdner strasse        Handelskai     6  brown
# 102        Handelskai        Neue Donau     6  brown
# 103        Neue Donau       Floridsdorf     6  brown

# %%
Start = vienna_data['Start']
Stop = vienna_data['Stop']
Line = vienna_data['Line']

edge_data = zip(sources, targets, weights)

for e in edge_data:
    src = e[0]
    dst = e[1]
    w = e[2]

    vienna_net.add_node(src, src, title=src)
    vienna_net.add_node(dst, dst, title=dst)
    vienna_net.add_edge(src, dst, value=w)

neighbor_map = got_net.get_adj_list()

# add neighbor data to node hover data
for node in got_net.nodes:
    node['title'] += ' Neighbors:<br>' + '<br>'.join(neighbor_map[node['id']])
    node['value'] = len(neighbor_map[node['id']])

vienna_net.show('Vienasubway.html')
# Out:
#         <iframe
#             width="100%"
#             height="750px"
#             src="Vienasubway.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ![Vienna%20Subway.png](attachment:Vienna%20Subway.png)

# %% [markdown]
# Fuente: [Kaggle](https://www.kaggle.com/lenapiter/vienna-subway-network)
#
# ### <center><span style="color:black">¿Qué?</span></center>
# Esta visualización es una representación de los recorridos del metro de la ciudad de Viena, Austria.
# + Existen dos atributos categóricos que indican el lugar de salida y parada del metro.
# + Existe otro atributo ordinal que indica la línea a la cual pertenece el viaje del metro en cuestión.
# ### <center><span style="color:black">¿Por qué?</span></center>
# + La visualización tiene como objetivo <span style="color:red">presentar</span> las conexiones existentes en los viajes del metro de la ciudad de Viena, Austria. De la visualización se puede <span style="color:red">disfrutar</span> la similitud que se  obtiene entre esta misma y el plano real del metro de Viena. También, se puede <span style="color:red">identificar</span> con precisión las conexiones del metro de Viena.
# ### <center><span style="color:black">¿Cómo?</span></center>
# + Se usó un modismo de redes y nodos que permiten que usuario navegue e interactue con la visualización.
# ### <center><span style="color:black">Marcas y Canales</span></center>
# + Marca de líneas y puntos.
# + Canal de posición espacial en ambos sentidos.
#
#
# - No existen problemas de oclusión para esta visualización. Sin embargo, se esperaría que la visualización plasmara el plano del metro de Viena tal cual como es en realidad, pero no es así, ya que solo se usan datos de conexiones entre los distintos viajes, más no se especifica la ubicación ni la longitud que existe entre un nodo a otro (estación a otra).
# - La mejora sugerida para esta visualización, sería en definitiva, poder asignar distancias entre nodos así como asignar un lugar específico a cada nodo para poder plasmar la visualización tal cual como es el metro de Viena en la vida real.
